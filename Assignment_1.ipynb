# %%
'''1. In the below elements which of them are values or an expression? eg:- values can be
   integer or string and expressions will be mathematical operators.'''

*       : (Expressions)

'hello' : (Value)

-87.8   : (Value)

-       : (Expression)

/       : (Expression)

+       : (Expression)

6       : (Value)
    
'''2. What is the difference between string and variable?'''

 'string': string is information which we stroe inside a variable,
    EX: Place= "Banglore", in this 'Banlglore' is a string stroed inside variabele(Place)

 'variabele': varaible strores a information(it may be a str,int,float, any information) in it, in 
             above example, variable 'Place' which stored a inforamtion Banglore(str)
    
'''3. Describe three different data types.'''
       
        1, stringe ('sharan'), it is the info stred within a single or double quote
        
        2, integer (1,2,3), integers are real  numbers
        
        3, floating no (10.5), floating numbers is a  decimal value
        
        4, complex no (2+3j),  combination of integer, alphabets,string,float etc
        
    
    
    
''' 4. What is an expression made up of? What do all expressions do?'''
    
    An expression is a construct made up of variables, operators,operands and method invocations, 
    which are constructed according to the syntax of the language, that evaluates to a single value.
    
    An expression is a combination of operators and operands that is interpreted to produce some other value. 
    In any programming language, an expression is evaluated as per the precedence of its operators.
    
    Expressions are representations of value. 
    
    EX: add(+), Multiplication(*),Division(/)
        a + b * c
    
'''5. This assignment statements, like spam = 10. What is the difference between an
       expression and a statement?'''
      An Expression Is combination of operators to perfom operation to get some value.
    
      An  statement does something, like creating a variable or displaying(printing) a value
        
        ex; a = 2
            b = 3
            spam = a + b
            print(spam)
            
'''6. After running the following code, what does the variable bacon contain?
       bacon = 22
       bacon + 1'''
        bacon = 22
        a = bacon + 1
        output= 23
        
        The variable bacon contains 22
        
'''7. What should the values of the following two terms be?
      spam + spamspam
      spam * 3 '''

       'spam'+ 'spamspam'  = spamspamspam
        'spam'*3 = spamspamspam
        
''' 8. Why is eggs a valid variable name while 100 is invalid?'''
    variable names start with (_, alphabets(lower(a) & upper(A))), ex, name= sharan, _place= KA,name_s,etc
    
    but variable shoud not starts with a numbers, it will be invail if you run,
    so 'eggs' is valide variable name since it starts with alpha(s)
    where as 100 is not vlide variable name since starting with numbers

'''9. What three functions can be used to get the integer, floating-point number, or string
      version of a value?'''
    str('variable')
    float('variable')
    int('variable')
    the above function used to convert a variable into integer, floating-point number, or string
      
'''  10. Why does this expression cause an error? How can you fix it?
      'i have eten' + 99 + 'burritos'''
   
    the above experesion is a combination of string and integer system can not perform a 
    concatination operation on combination string and integer, the data type must be same 
    to fix it convert all data into same format
    
    'i have eten' + '99' + 'burritos'   ; if you run this it will work now

# %% [markdown]
# # Thank You!!
