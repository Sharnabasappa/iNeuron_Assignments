# %%
"""1. What are escape characters, and how do you use them?"""

Following are the escape characters used in pyhton

code   Result

\'    Single Quote
\\    Backslash
\n    New Line
\r    Carriage Return
\t    Tab
\b    Backspace
\f    Form Feed
\ooo  Octal value
\xhh  Hex value

Ex of abpve escape charcters :

\'    
txt = 'It\'s alright.'
print(txt) 
  o/p = It's alright
 
\\
txt = "This will insert one \\ (backslash)."
print(txt) 
  o/p = this will insert one \ (backlash).
 
\n
txt = "Hello\nWorld!"
print(txt) 
 o/p = Hello
       World!
        
\r   
txt = "Hello\rWorld!"
print(txt) 
 o/p = Hello
       World!
        
\t
txt = "Hello\tWorld!"
print(txt) 
 o/p =  Hello World!

\b    
#This example erases one character (backspace):
txt = "Hello \bWorld!"
print(txt) 
 o/p = HelloWorld!

\ooo    
#A backslash followed by three integers will result in a octal value:
txt = "\110\145\154\154\157"
print(txt) 
  o/p = Hello
    
\xhh
#A backslash followed by an 'x' and a hex number represents a hex value:
txt = "\x48\x65\x6c\x6c\x6f"
print(txt) 
 o/p = Hello
    
"""2. What do the escape characters n and t stand for?"""

\n , this letter changes the line and print character in a next line 
EX:
    
txt = "Hello\nWorld!"
print(txt) 
 o/p = Hello
       World!

\t,  this letter creat a one tab space
EX:
txt = "Hello\tWorld!"
print(txt) 
 o/p =  Hello World!

"""3. What is the way to include backslash characters in a string?"""

\\  with this double backlash i will be able to oncelude a backlash inside a sting
EX:
    
txt = "This will insert one \\ (backslash)."
print(txt) 
  o/p = this will insert one \ (backlash).
 
"""4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the
      word Howl's not escaped a problem?"""
 
sice the string "Howl's Moving Castle" is enclosed by double coat,  if single coat inside this it wont escape

"""5. How do you write a string of newlines if you don't want to use the n character?"""


I will write a string of new lines using '\n' and also using 'print()' at the end of code able to  change the line,

EX;
b= '[1,2,3,4]'
for num in range(len(b)):
    print(num, end = ' ')
    print()
    
"""6. What are the values of the given expressions?"""

'Hello,world!'[1]   = 'e'

'Hello,world!'[0:5]  = 'Hello'

'Hello,world!'[:5]   = 'Hello'

'Hello,world!'[3:]  =  'lo,world!'
    
"""7. What are the values of the following expressions?"""
    
'Hello'.upper()    = 'HELLO'
    
'Hello'.upper().isupper()  = True

'Hello'.upper().lower()   = 'hello'

"""8. What are the values of the following expressions?"""

'Remember,remember,the fifth of july.'.split()  

 o/p = ['Remember,remember,the', 'fifth', 'of', 'july.']

'-'.join('There can only one.'.split())

 o/p = 'There-can-only-one.'
    
"""9. What are the methods for right-justifying, left-justifying, and centering a string?"""

Following methods used for justifying a strings are:
    
right-justifying:
    
    .rjust()
    
    Ex:
        a = 'sharan'
        
        a.rjust(10, '#')          # where 10 is total stringe width 
        
        output= '####sharan'

left-justifying:
     
    .ljust()
    
    EX:
        a = 'sharan'
        
        a.ljust(10,  '#')          # where 10 is total stringe width 
        
        output = 'sharan####'

centering:
    
    .center()
    
    Ex:
        a = 'sharan'
        
        a.center(10, '#')            # where 10 is total stringe width 
        
        output = ''##sharan##''
        
"""10. What is the best way to remove whitespace characters from the start or end?"""
    
a = ' Howl"s Moving Castle '

a.lstrip()    # this  method to remove whitespace and characters only from the beginning of a string.

output = 'Howl"s Moving Castle '

a.rstrip() # this  method to remove whitespace and characters only from the End of a string.
    
output = ' Howl"s Moving Castle'

# %%
Thank You!
