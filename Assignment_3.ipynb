# %%
'''1 Why are functions advantageous to have in your programs?'''

Functions reduce the need for duplicate code and also it increases the reusability of code. 
This makes programs shorter, easier to read, and easier to update. and saves the programming time

'''2. When does the code in a function run: when it's specified or when it's called?'''

code in a function run When a function is "called" the program "leaves" the current section of code and 
begins to execute the  first line inside the function.

'''3. What statement creates a function?'''

The def keyword is followed by the function name with round brackets and a colon. creats a function

ex; def add(a,b):
    return a +b

'''4. What is the difference between a function and a function call?'''

A function is a block of code that does a particular operation and returns a result. It usually accepts inputs 
as parameters and returns a result.

A function call is the code used to pass control to a function. and call function by passing an arguments

'''5. How many global scopes are there in a Python program? How many local scopes?'''

When you use an unqualified name inside a function, Python searches three scopes—the local (L), then the global (G), and 
then the built-in (B)—and stops at the first place the name is found.

there are foure local  scope in pythom: 1,local, 2,enclosing, 3,global, and 4,built-in.
    
    there is only one type of global python scope per programe
    
'''6. What happens to variables in a local scope when the function call returns?'''

When the execution of the function terminates (returns), the local variables are destroyed. Codelens helps you 
visualize this because the local variables disappear after the function returns.


'''7. What is the concept of a return value? Is it possible to have a return value in an expression?'''

A return statement is used to end the execution of the function call and “returns” the result 
(value of the expression following the return keyword) to the caller. 
The statements after the return statements are not executed. 
If the return statement is without any expression, then the special value None is returned.
yes its possible to return a value after expression

'''8. If a function does not have a return statement, what is the return value of a call to that function?'''

If a function does not have a return statement it will  return or undefined

'''9. How do you make a function variable refer to the global variable?'''

function variable refer to global variable when it is defined before function.

If you want to refer to a global variable in a function, you can use the global keyword to declare 
which variables are global.

The basic rules for global keyword in Python are:
When we create a variable inside a function, it is local by default.
When we define a variable outside of a function, it is global by default.
We use global keyword to read and write a global variable inside a function.


'''10. What is the data type of None?'''
data type of none is : NoneType

The None keyword is used to define a null value, or no value at all. None is not the same as 0, False, or an empty string.

None is a data type of its own (NoneType) and only None can be None.

'''11. What does the sentence import areallyourpetsnamederic do?'''

it import a module named areallyourpetsnamederic but 
its not an python module question

'''12. If you had a bacon() feature in a spam module, what would you call it after importing spam?'''

spam.bacon()

'''13. What can you do to save a programme from crashing if it encounters an error?'''

We can use Exception handling and Method and try and except statement To save our programme from crashing

When it encounters an error, the control is passed to the except block, skipping the code in between. As seen in the above code,
we have moved our code inside a try and except statement. Try running the program and it should throw an error message instead of
crashing the program

'''14. What is the purpose of the try clause? What is the purpose of the except clause?'''


Try:
    The try block lets you test a block of code for errors.


Except:
    The except block lets you handle the error.
