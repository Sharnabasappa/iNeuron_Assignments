# %%
'''1. What does an empty dictionary"s code look like?'''

empty Dictionary look like

a= {}   where, a = variable

"""2. What is the value of a dictionary value with the key 'foo' and the value 42?"""

a = {'foo':42}  whre a =  variable

a.keys(),   able to list all the keys of dictionary

a.values(), able to list all the value of dictionary

The value of above dictionary(a) is 42

"""3. What is the most significant distinction between a dictionary and a list?"""

A list is an ordered sequence of objects, whereas dictionaries are unordered sets. However, 
the main difference is that items in dictionaries are accessed via keys and not via their position.
and both are mutable/able to modify

dictionary consist of key - value pair

"""4. What happens if you try to access spam['foo']if spam is{'bar':100}?"""

spam = {'bar':100}
spam['foo']

   after reunning this i was getting a below error
    KeyError                                  Traceback (most recent call last)
~\AppData\Local\Temp/ipykernel_11180/3999281786.py in <module>
----> 1 spam['foo']

KeyError: 'foo'
    
    since item of dictionary able acces through keys, but the above key('foo') not there is variable dictionary
    

"""5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam
and 'cat' in spam.keys()?"""

There is no difference one will checks in key's in dictionary and second one will checks in all/one of the key's

spam= {'cat':251, "name":'sharan', 'place':'cat'}

'cat' in spam:
    
    in this the operator try to search or checks weathere there is 'cat' key in dictionary
            ex:
               'cat' in spam
                
                output= True
                
'cat' in spam.keys():
    
    in this operator checks weathere there is a value 'cat' in one of the key's
    
             ex:
               'cat' in spam.keys()
                
                output= True
                
    
"""7. What is a shortcut for the following code?"""

if 'color' not in spam:
    spam['color']= 'black'

The short cut used for above code is 

    spam.setdefault ('color','black')
    
"""8. How do you "pretty print" dictionary values using which module and function?"""

using a  this below  module and function can print a pretty print a dictionary

pprint.pprint()

  EX;
import pprint

def foo():
    print(42)

import inspect
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(inspect.getsource(foo))

output:
    'def foo():\n    print(42)\n'
    

A prettyprinter takes blocks of code and prints them in an aesthetically pleasing fashion, presenting the characters with line breaks 
and indentations to make the code comprehensible.

# %%
Thank YOu
